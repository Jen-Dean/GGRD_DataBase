# %%
import pandas as pd
import openpyxl

# %%
#Pulling the Excel File & Sheet
path = "STATS/all_stars_2018/test.xlsx"
stats_df = pd.read_excel(path, sheet_name="SK", engine="openpyxl")
# Out:
# /Users/jenniferdean/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:300: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
#Check that the data came through
stats_df
# Out:
#      Per 1     Home       2      17 Unnamed: 4 Unnamed: 5     3     4  \
# 0    Jam #  Jam Row  Jammer  Points   Team Pts        +/-  Lost  Lead
# 1        1        4    1706       3          3          3   NaN     1
# 2      NaN      NaN     NaN     NaN        NaN        NaN   NaN   NaN
# 3        2        5     010       2          2          2   NaN     1
# 4      NaN      NaN     NaN     NaN        NaN        NaN   NaN   NaN
# ..     ...      ...     ...     ...        ...        ...   ...   ...
# 225    NaN      NaN   Per 2     NaN        NaN        NaN   NaN   NaN
# 226    NaN      NaN   Total     NaN        NaN        NaN   NaN   NaN
# 227     20      NaN   Per 1     NaN        NaN        NaN   NaN   NaN
# 228    NaN      NaN   Per 2     NaN        NaN        NaN   NaN   NaN
# 229    NaN      NaN   Total     NaN        NaN        NaN   NaN   NaN
#
#     Unnamed: 8     5  ... Unnamed: 21    22    23 Unnamed: 24    24   25   26  \
# ...

# %%
# Drop all NA columns & Rows // Reset the header of the dataframe
stats_df = stats_df.dropna(axis=1, how="all")
stats_df = stats_df.dropna(axis="index", how="all").reset_index()
stats_df = stats_df = stats_df.rename(columns=stats_df.iloc[0]).drop(stats_df.index[0])
stats_df
# Out:
#        0 Jam # Jam Row Jammer Points Team Pts  +/- Lost Lead Lead +/-  ...  \
# 1      1     1       4   1706      3        3    3  NaN    1        3  ...
# 2      3     2       5    010      2        2    2  NaN    1        2  ...
# 3      5     3       6   1706      4        4    4  NaN    1        4  ...
# 4      7     4       7   1978      4        4    4  NaN    1        4  ...
# 5      9     5       8    010      0        0  -13    1  NaN      NaN  ...
# ..   ...   ...     ...    ...    ...      ...  ...  ...  ...      ...  ...
# 139  225   NaN     NaN  Per 2    NaN      NaN  NaN  NaN  NaN      NaN  ...
# 140  226   NaN     NaN  Total    NaN      NaN  NaN  NaN  NaN      NaN  ...
# 141  227    20     NaN  Per 1    NaN      NaN  NaN  NaN  NaN      NaN  ...
# 142  228   NaN     NaN  Per 2    NaN      NaN  NaN  NaN  NaN      NaN  ...
# 143  229   NaN     NaN  Total    NaN      NaN  NaN  NaN  NaN      NaN  ...
#
#      +/- Lost Lead Lead +/- Call  Inj   NI Trips Time Pts / Min
# ...

# %%
#Find where Period 1 and Period 2 begin and end
#stats_df.loc[stats_df[0] == "Per 2"]
#stats_df.loc[stats_df[0] == "Per 2 Total"]

# %%
#Find where Period 1 and Period 2 begin and end
#stats_df[42:81]
#stats_df[:39]

# %%
#Set two dataframes with the different periods
period_one_stats_df = stats_df[:38]
period_two_stats_df = stats_df[42:80]

# %%
#Reset the Indexes
period_two_stats_df = period_two_stats_df.reset_index(drop=True)
period_one_stats_df = period_one_stats_df.reset_index(drop=True)

# %%
#Fill NaN with Zeros
period_one_stats_df = period_one_stats_df.fillna("0")
period_two_stats_df = period_two_stats_df.fillna("0")

# %%
#Drop original Index Column
period_two_stats_df = period_two_stats_df.drop([0], axis = 1)
period_one_stats_df = period_one_stats_df.drop([0], axis = 1)

# %%
#Check Data
period_two_stats_df
period_one_stats_df
# Out:
#     Jam # Jam Row Jammer Points Team Pts  +/- Lost Lead Lead +/- Call  ...  \
# 0       1       4   1706      3        3    3    0    1        3    1  ...
# 1       2       5    010      2        2    2    0    1        2    1  ...
# 2       3       6   1706      4        4    4    0    1        4    1  ...
# 3       4       7   1978      4        4    4    0    1        4    1  ...
# 4       5       8    010      0        0  -13    1    0        0    0  ...
# 5       6       9     56      2        2    2    0    1        2    1  ...
# 6       7      10   1706      4        4    4    0    1        4    1  ...
# 7       8      11   1978      0        0    0    0    1        0    1  ...
# 8       9      12   1706      0        0  -14    1    0        0    0  ...
# 9      10      13    010      0        0    0    0    1        0    1  ...
# 10     11      14     56      5        5    5    0    1        5    1  ...
# ...
